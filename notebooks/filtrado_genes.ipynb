# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
RUTA = "C:/Users/emanc/OneDrive - Universidad de Extremadura (1)/MUBinf/09.TFM/Datos/"
ARCHIVO = "lung_cancer_filtrado.h5ad"

# %%
adata= sc.read_h5ad(f"{RUTA}{ARCHIVO}")

# %%
print(adata.X[:5, :5].toarray())

# %%
print(adata.layers.keys())

# %%
groupby_column = 'cell_type'
sc.tl.rank_genes_groups(adata, groupby=groupby_column, method='t-test')

# %%
sc.pl.rank_genes_groups_dotplot(adata, n_genes=4, show=True)

# %%
marker_genes_df = pd.DataFrame(adata.uns['rank_genes_groups']['names'])
print(marker_genes_df.head(5))

# %%
print(adata.var.head(20))

# %%
adata.var['gene_name'] = adata.var['feature_name'].str.extract(r'^(.+?)_ENSG')[0]
